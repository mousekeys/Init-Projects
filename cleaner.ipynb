# %%
import pandas as pd
import numpy as np

# %%
df.head(5)
# Out:
#                                                Title  \
# 0  Flat System House On Sale At Budhanikantha : H...
# 1  21 Aana Beautiful House : House For Sale In Bu...
# 2  Beautiful To Floor House : House For Sale In D...
# 3  Modern Architecture Bungalow House : House For...
# 4  Modern Bungalow House : House For Sale In Golf...
#
#                                     Address       City      Price  Bedroom  \
# 0  Budhanikantha, Budhanilkantha, Kathmandu  Kathmandu   90000000        6
# 1        Pasikot, Budhanilkantha, Kathmandu  Kathmandu   80000000        5
# 2               Dhapasi, Dhapasi, Kathmandu  Kathmandu   70000000        5
# 3           baluwatar, Baluwatar, Kathmandu  Kathmandu  130000000        6
# 4             Golfutar, Golfutar, Kathmandu  Kathmandu  100000000        6
#
#    Bathroom  Floors  Parking  Face    Year Views           Area  \
# 0         3     2.0       10  West  2073.0    17   1-0-0-0 Aana
# ...

# %%
df.count()
# Out:
# Title         2211
# Address       2211
# City          2211
# Price         2211
# Bedroom       2211
# Bathroom      2211
# Floors        1039
# Parking       2211
# Face          2211
# Year           582
# Views         2211
# Area          2211
# Road          2211
# Road Width    2211
# Road Type     1426
# Build Area    2211
# Posted        2211
# Amenities     2211
# dtype: int64

# %%
df=pd.read_csv('house.csv')

# %%
df.loc[:,'Build Area'].dropna()
# Out:
# 0       18-0-0-0 Aana
# 1       0-14-0-0 Aana
# 2       10-1-0-0 Aana
# 3        0-7-1-0 Aana
# 4       0-14-2-0 Aana
#             ...
# 2206     N/A Sq. Feet
# 2207     N/A Sq. Feet
# 2208     N/A Sq. Feet
# 2209     N/A Sq. Feet
# 2210          13 Aana
# Name: Build Area, Length: 2211, dtype: object

# %%
a=[1,2,3,4,5]
df=pd.DataFrame(a)
df.empty
# Out:
# False

# %%
a=pd.Series()
a.empty
# Out:
# True

# %%
df.loc[:,'Year'].unique()
# Out:
# array([2073., 2071., 2017., 2070., 2074., 2019., 2065., 2075., 2076.,
#        2056.,   nan, 2069., 2018., 2067., 2068., 2077., 2020., 2003.,
#        2013., 2058., 2010., 2014., 2009., 2012., 2001., 2000., 2015.,
#        2072., 2002., 2016., 2007., 2066., 2050., 2064., 2006., 2045.,
#        2060., 2005., 2049., 2063., 2062., 2052., 2011., 2059., 2042.,
#        2046., 2044., 2025., 1994.])

# %%
df.loc[df['Build Area']=='N/A Ropani']
# Out:
#                                                   Title  \
# 175                    Land For Sale In Bode, Bhaktapur
# 873   5 Ropani Land For Sale At Golfutar! : Land For...
# 925      Land For Sale In Dahachowk, Khahare, Kathmandu
# 929             Land For Lease In DDC Chowk, Biratnagar
# 1053                    Land For Sale In Rupakot, Kaski
# 1119                   Land For Sale In Patan, Lalitpur
# 1120              Land For Sale In Koteshwor, Kathmandu
# 1539               House For Sale In Kalanki, Kathmandu
# 1857           House For Sale In Maharajgunj, Kathmandu
# 1911                  Land For Sale In Dhading, Dhading
# 1970        House For Rent In Budhanilkantha, Kathmandu
#
#                                                 Address        City  \
# 175          Nilbarahi Bode, Bhaktapur, Bode, Bhaktapur   Bhaktapur
# 873     Golfutar basketball ground, Golfutar, Kathmandu   Kathmandu
# 925   Khahare chowk dahachowk, Dahachowk, khahare, K...   Kathmandu
# ...

# %%
df.loc[:,'Build Area'].unique()
# Out:
# array(['18-0-0-0 Aana', '0-14-0-0 Aana', '10-1-0-0 Aana', '0-7-1-0 Aana',
#        '0-14-2-0 Aana', '0-8-3-1 Aana', '0-6-5-0 Aana', '0-9-3-2 Aana',
#        '2394 Aana', '7 Aana', '2500 Aana', '2700 Sq. Feet',
#        '2100 Sq. Feet', '2700 Aana', '112 Sq. Meter', '3-0-2 Aana',
#        '4 Aana', '2200 Sq. Feet', '2000 Sq. Feet', '3 Aana',
#        '4000 Sq. Feet', '0-3-1-2 Sq. Feet', '1736 Dhur', '3500 Aana',
#        '0-4-0-0 Aana', '1900 Sq. Feet', '2500 Sq. Feet', '750 Aana',
#        '650 Sq. Feet', '990 Sq. Feet', '950 Sq. Feet', '6.25 Dhur',
#        '0-4.0.0 Aana', '0-3-2-0 Aana', '1650 Sq. Feet', '1195 Sq. Feet',
#        '10 Aana', '1100 Aana', '5 Aana', '850 Sq. Feet', '0.5.3.0 Aana',
#        '1583 Sq. Feet', '1280 Sq. Feet', '4 Sq. Feet', '1200 Sq. Feet',
#        '1350 Sq. Feet', '0-2-2-1 Aana', '1-1-0 Ropani',
#        '95/16/11/7 Ropani', '3.2 Aana', '646 Sq. Feet', '0-5-1 Aana',
#        '14 Aana', '1500 Sq. Feet', '3922.08 Sq. Feet', '5000 Sq. Feet',
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 462 entries, 0 to 2210
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       462 non-null    object
#  1   Address     462 non-null    object
#  2   City        462 non-null    object
#  3   Price       462 non-null    int64
#  4   Bedroom     462 non-null    int64
#  5   Bathroom    462 non-null    int64
#  6   Floors      320 non-null    float64
#  7   Parking     462 non-null    int64
#  8   Face        462 non-null    object
#  9   Year        273 non-null    float64
#  10  Views       462 non-null    object
#  11  Area        462 non-null    object
#  12  Road        462 non-null    object
#  13  Road Width  462 non-null    object
#  14  Road Type   351 non-null    object
#  15  Build Area  462 non-null    object
#  16  Posted      462 non-null    object
#  17  Amenities   462 non-null    object
# dtypes: float64(2), int64(4), object(12)
# ...

# %%
df.count()
# Out:
# Title         1280
# Address       1280
# City          1280
# Price         1280
# Bedroom       1280
# Bathroom      1280
# Floors         704
# Parking       1280
# Face          1280
# Year           555
# Views         1280
# Area          1280
# Road          1280
# Road Width    1280
# Road Type      959
# Build Area    1280
# Posted        1280
# Amenities     1280
# dtype: int64

# %%
df.count()
# Out:
# Title         462
# Address       462
# City          462
# Price         462
# Bedroom       462
# Bathroom      462
# Floors        320
# Parking       462
# Face          462
# Year          273
# Views         462
# Area          462
# Road          462
# Road Width    462
# Road Type     351
# Build Area    462
# Posted        462
# Amenities     462
# dtype: int64

# %%
df=df.loc[df['Build Area']!='N/A Ropani']
